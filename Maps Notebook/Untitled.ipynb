# %%
import pandas as pd
import folium
from IPython.display import IFrame

# Step 1: Data Collection
crime_data = pd.read_csv('crime_data.csv')  # Replace 'crime_data.csv' with the actual filename

# Step 2: Drop rows with missing latitude or longitude values
crime_data = crime_data.dropna(subset=['Latitude', 'Longitude'])

# Step 3: Create a map centered at a specific location
crime_map = folium.Map(location=[crime_data['Latitude'].mean(), crime_data['Longitude'].mean()], zoom_start=10)

# Step 4: Add markers for each crime location
for index, row in crime_data.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup=row['Crime_Type']).add_to(crime_map)

# Step 5: Save the map to an HTML file
crime_map.save('crime_map.html')

# Display the map in the notebook using IFrame
IFrame('crime_map.html', width=700, height=500)
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="crime_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Step 1: Data Collection
crime_data = pd.read_csv('crime_data.csv')  # Replace 'crime_data.csv' with the actual filename

# Step 2: Data Preprocessing
# Drop rows with missing latitude or longitude values
crime_data.dropna(subset=['Latitude', 'Longitude'], inplace=True)

# Convert latitude and longitude to Point geometries
crime_data['Coordinates'] = crime_data.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)
crime_geo = gpd.GeoDataFrame(crime_data, geometry='Coordinates')

# Step 3: Spatial Analysis (Clustering)
kmeans = KMeans(n_clusters=5)  # Adjust the number of clusters as needed
crime_geo['Cluster'] = kmeans.fit_predict(crime_geo[['Longitude', 'Latitude']])

# Step 4: Visualization
fig, ax = plt.subplots(figsize=(10, 10))
crime_geo.plot(ax=ax, column='Cluster', legend=True, cmap='viridis', markersize=5)
plt.title('Crime Hotspots')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
import pandas as pd
import folium
from IPython.display import IFrame

# Step 1: Data Collection
crime_data = pd.read_csv('crime_data.csv')  # Replace 'crime_data.csv' with the actual filename

# Step 2: Drop rows with missing latitude or longitude values
crime_data = crime_data.dropna(subset=['Latitude', 'Longitude'])

# Step 3: Create a map centered at a specific location
crime_map = folium.Map(location=[crime_data['Latitude'].mean(), crime_data['Longitude'].mean()], zoom_start=10)

# Step 4: Add markers for each crime location
for index, row in crime_data.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup=row['Crime_Type']).add_to(crime_map)

# Step 5: Save the map to an HTML file
crime_map.save('crime_map.html')

# Display the map in the notebook using IFrame
IFrame('crime_map.html', width=700, height=500)
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="crime_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Step 1: Data Collection
crime_data = pd.read_csv('crime_data.csv')  # Replace 'crime_data.csv' with the actual filename

# Step 2: Data Preprocessing
# Drop rows with missing latitude or longitude values
crime_data.dropna(subset=['Latitude', 'Longitude'], inplace=True)

# Convert latitude and longitude to Point geometries
crime_data['Coordinates'] = crime_data.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)
crime_geo = gpd.GeoDataFrame(crime_data, geometry='Coordinates')

# Step 3: Spatial Analysis (Clustering)
kmeans = KMeans(n_clusters=5)  # Adjust the number of clusters as needed
crime_geo['Cluster'] = kmeans.fit_predict(crime_geo[['Longitude', 'Latitude']])

# Step 4: Visualization
fig, ax = plt.subplots(figsize=(10, 10))
crime_geo.plot(ax=ax, column='Cluster', legend=True, cmap='viridis', markersize=5)
plt.title('Crime Hotspots')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
import pandas as pd
import folium
import mysql.connector
from IPython.display import IFrame

# Step 1: Establish connection to MySQL server
connection = mysql.connector.connect(
    host="localhost",
    user="69Shashank69Sonji69",
    password="Sonji@2534",
    database="Hackathon"
)

# Step 2: Query data from MySQL server
query = "SELECT Latitude, Longitude, Crime_Type FROM crime_table"  # Replace 'crime_table' with the name of your table
crime_data = pd.read_sql(query, connection)

# Step 3: Drop rows with missing latitude or longitude values
crime_data = crime_data.dropna(subset=['Latitude', 'Longitude'])

# Step 4: Create a map centered at a specific location
crime_map = folium.Map(location=[crime_data['Latitude'].mean(), crime_data['Longitude'].mean()], zoom_start=10)

# Step 5: Add markers for each crime location
for index, row in crime_data.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup=row['Crime_Type']).add_to(crime_map)

# Step 6: Save the map to an HTML file
crime_map.save('crime_map.html')

# Display the map in the notebook using IFrame
IFrame('crime_map.html', width=700, height=500)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:323, in CMySQLConnection._open_connection(self)
#     322 try:
# --> 323     self._cmysql.connect(**cnx_kwargs)
#     324     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Access denied for user '69Shashank69Sonji69'@'localhost' (using password: YES)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[8], line 7
#       4 from IPython.display import IFrame
#       6 # Step 1: Establish connection to MySQL server
# ----> 7 connection = mysql.connector.connect(
#       8     host="localhost",
#       9     user="69Shashank69Sonji69",
#      10     password="Sonji@2534",
# ...

# %%
import pandas as pd
import folium
import mysql.connector
from IPython.display import IFrame

# Step 1: Establish connection to MySQL server
connection = mysql.connector.connect(
    host="localHost",
    user="root",
    password="Sonji@2534",
    database="Hackathon"
)

# Step 2: Query data from MySQL server
query = "SELECT Latitude, Longitude, Crime_Type FROM crime_data"  # Replace 'crime_table' with the name of your table
crime_data = pd.read_sql(query, connection)

# Step 3: Drop rows with missing latitude or longitude values
crime_data = crime_data.dropna(subset=['Latitude', 'Longitude'])

# Step 4: Create a map centered at a specific location
crime_map = folium.Map(location=[crime_data['Latitude'].mean(), crime_data['Longitude'].mean()], zoom_start=10)

# Step 5: Add markers for each crime location
for index, row in crime_data.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup=row['Crime_Type']).add_to(crime_map)

# Step 6: Save the map to an HTML file
crime_map.save('crime_map.html')

# Display the map in the notebook using IFrame
IFrame('crime_map.html', width=700, height=500)
# Out:
# C:\Users\sonji\AppData\Local\Temp\ipykernel_12960\584662597.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   crime_data = pd.read_sql(query, connection)
#         <iframe
#             width="700"
#             height="500"
#             src="crime_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
